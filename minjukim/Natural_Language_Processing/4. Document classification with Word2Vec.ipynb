# %% [markdown]
# ## 임베딩 읽어들이기

# %%
def load_word_embeddings(path, num_vecs=30000):
    embeddings, vocab = [], []
    f = open(path, "r", encoding="utf-8").readlines()[1:num_vecs + 1]
    for line in f:
        splited_line = line.strip().split(" ")
        word = splited_line[0]
        vec = [float(el) for el in splited_line[1:]]
        vocab.append(word)
        embeddings.append(vec)
    word_to_index = {word: idx for idx, word in enumerate(vocab)}
    index_to_word = {idx: word for idx, word in enumerate(vocab)}
    vocab_size = len(vocab)
    return embeddings, vocab, word_to_index, index_to_word, vocab_size

# %%
embeddings, vocab, word_to_index, index_to_word, vocab_size = load_word_embeddings("embedding/word2vec.txt")

# %%
# word_to_index['폰']
embeddings[word_to_index['폰']]
# Out:
# [0.40756693,
#  0.10399851,
#  0.068960644,
#  -0.06728446,
#  -0.04627618,
#  0.11270078,
#  -0.5182983,
#  0.010880889,
#  0.26014423,
#  0.12969808,
#  0.131198,
#  -0.12764914,
#  0.5413734,
#  -0.5105737,
#  0.2966412,
#  -0.21341276,
#  0.42202273,
#  0.39021936,
#  -0.24918261,
#  -0.21797988,
#  -0.038810458,
#  0.19363868,
#  0.33906236,
#  -0.028319051,
#  0.016351104,
#  0.104889855,
#  -0.22713748,
#  -0.1870471,
#  0.10869626,
#  -0.025511548,
#  0.76009697,
#  0.11837887,
#  0.69456154,
#  0.1168128,
#  -0.033387233,
#  -0.04071568,
#  0.39109078,
#  -0.277839,
#  0.48387015,
#  0.17641912,
#  0.23689614,
#  0.048578106,
#  -0.33016205,
#  0.021788016,
#  0.12018698,
#  -0.5191495,
#  -0.034779374,
#  0.20541409,
#  0.47657725,
#  0.15663806,
#  -0.86120975,
#  0.025745058,
#  0.45544395,
#  0.10810242,
#  0.2953998,
#  -0.59026104,
#  0.2927954,
#  -0.39751402,
#  -0.7756063,
#  -0.35340938,
#  -0.08575064,
#  0.054851316,
#  0.005910598,
#  -0.018256905,
#  0.02538809,
#  -0.23107912,
#  0.31236434,
#  -0.07843713,
#  -0.10905662,
#  -1.1090585,
#  0.25013113,
#  -0.293665,
#  0.41080025,
#  0.2516035,
#  -0.06762564,
#  0.103078015,
#  0.07614898,
#  -0.1925965,
#  -0.0055441773,
#  -0.0038529004,
#  -0.5462455,
#  -0.38766673,
#  0.05069547,
#  0.20587923,
#  -0.19065419,
#  -0.23728353,
#  0.34277302,
#  0.55493283,
#  0.24584483,
#  0.16068055,
#  -0.0374398,
#  0.01905555,
#  0.3323424,
#  0.20831215,
#  -0.4139008,
#  0.14288166,
#  0.13722216,
#  -0.1301512,
#  -0.2032975,
#  -0.3139576]

# %% [markdown]
# ## 관심 기능 정의

# %%
functions = ["배터리", "촬영", "디자인", "화면", "OS", "색"]
function_size = len(functions)

# %% [markdown]
# ## 거리 행렬 구하기

# %%
import numpy as np
from scipy.spatial import distance

distance_matrix = np.zeros([function_size, vocab_size], dtype=np.float16)

# %%
for func_idx, func in enumerate(functions):
    func_vec = embeddings[word_to_index[func]]
    for word_idx, word_vec in enumerate(embeddings):
        distance_matrix[func_idx, word_idx] = distance.euclidean(func_vec, word_vec)

# %%
distance_matrix
# Out:
# array([[3.75 , 4.094, 3.812, ..., 3.172, 3.152, 3.168],
#        [4.215, 4.484, 4.266, ..., 3.525, 3.707, 3.547],
#        [3.682, 3.998, 3.674, ..., 2.922, 3.133, 3.115],
#        [3.807, 4.19 , 3.81 , ..., 3.295, 3.426, 3.342],
#        [3.82 , 4.258, 3.99 , ..., 3.201, 3.264, 3.162],
#        [4.29 , 4.547, 4.25 , ..., 3.566, 3.541, 3.682]], dtype=float16)

# %% [markdown]
# ## 가중치 행렬 구하기

# %%
# 정규화

weight_matrix = np.zeros([function_size, vocab_size], dtype=np.float16)
for func_idx, per_func_distances in enumerate(distance_matrix):
    values = np.exp(-(per_func_distances ** 2) / 15)
    mean = np.mean(values)
    weight_matrix[func_idx, :] = values - mean + 0.5

# %%
weight_matrix
# Out:
# array([[0.4458, 0.381 , 0.4338, ..., 0.5654, 0.57  , 0.5664],
#        [0.4368, 0.3926, 0.428 , ..., 0.5674, 0.5312, 0.5635],
#        [0.4202, 0.3596, 0.4216, ..., 0.581 , 0.535 , 0.5386],
#        [0.4539, 0.3835, 0.4531, ..., 0.5586, 0.531 , 0.549 ],
#        [0.4436, 0.3645, 0.4116, ..., 0.5703, 0.5576, 0.579 ],
#        [0.4136, 0.372 , 0.42  , ..., 0.548 , 0.553 , 0.525 ]],
#       dtype=float16)

# %% [markdown]
# ## 가중치 행렬 시각화

# %%
from bokeh.plotting import figure
from bokeh.layouts import gridplot
from bokeh.io import output_notebook, show

output_notebook()
def make_plot(title, hist, edges):
    p = figure(title=title, tools='', background_fill_color="#fafafa")
    p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:],
           fill_color="navy", line_color="white", alpha=0.5)
    p.y_range.start = 0
    p.grid.grid_line_color="white"
    return p
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
plots = []
for func_idx, func in enumerate(functions):
    hist, edges = np.histogram(weight_matrix[func_idx], density=True, bins=50)
    plots.append(make_plot(func, hist, edges))
show(gridplot(plots, ncols=2, plot_width=400, plot_height=300, toolbar_location=None))
# Out:
#   <div class="bk-root" id="e98dc4fe-eb68-4c86-b7bb-41731ea92cd4" data-root-id="1215"></div>

# %% [markdown]
# 정규분포를 가운데 절반에서 자른 모양

# %%
battery_weights = [(token, score) for token, score in zip(vocab, weight_matrix[0])]

# %%
sorted(battery_weights, key=lambda x: x[1], reverse=True)
# Out:
# [('배터리', 1.055),
#  ('밧데리', 0.9185),
#  ('표준형', 0.7617),
#  ('터리', 0.7246),
#  ('대용량', 0.723),
#  ('충전기', 0.703),
#  ('러닝', 0.6924),
#  ('슬림형', 0.673),
#  ('발열', 0.6694),
#  ('리튬', 0.668),
#  ('상판', 0.664),
#  ('폴리머', 0.664),
#  ('대기전력', 0.6636),
#  ('커넥터', 0.657),
#  ('키트', 0.6553),
#  ('급속', 0.655),
#  ('간당간당', 0.655),
#  ('기판', 0.6514),
#  ('TTA', 0.649),
#  ('회로', 0.6436),
#  ('껍데기', 0.6426),
#  ('오래간다', 0.6426),
#  ('여분', 0.639),
#  ('mAH', 0.639),
#  ('나사', 0.6377),
#  ('밧', 0.6357),
#  ('접점', 0.635),
#  ('연식', 0.6323),
#  ('단다고', 0.6313),
#  ('접지', 0.6304),
#  ('극심', 0.6304),
#  ('커버도', 0.6294),
#  ('단다', 0.629),
#  ('배불뚝이', 0.6284),
#  ('RMAA', 0.6284),
#  ('Ap', 0.6274),
#  ('뽀대', 0.627),
#  ('외장형', 0.627),
#  ('런타임', 0.627),
#  ('주범', 0.627),
#  ('암페어', 0.6265),
#  ('소모율', 0.6265),
#  ('타폰', 0.6265),
#  ('리시버', 0.6255),
#  ('쿨러', 0.6255),
#  ('놑', 0.625),
#  ('가로길이', 0.625),
#  ('ISP', 0.625),
#  ('뒷부분', 0.623),
#  ('뒤쪽', 0.623),
#  ('짹', 0.623),
#  ('tta', 0.623),
#  ('교실', 0.6226),
#  ('하판', 0.6226),
#  ('에너지', 0.622),
#  ('가품', 0.622),
#  ('정확도', 0.6206),
#  ('턱없이', 0.6206),
#  ('옹이', 0.619),
#  ('리소스', 0.619),
#  ('푸딩', 0.619),
#  ('그중', 0.619),
#  ('절벽', 0.619),
#  ('거미줄', 0.619),
#  ('EBH', 0.619),
#  ('넓이', 0.618),
#  ('콘센트', 0.6177),
#  ('레베', 0.6177),
#  ('ap', 0.617),
#  ('타기', 0.6167),
#  ('변강', 0.616),
#  ('강쇠', 0.616),
#  ('코랄', 0.616),
#  ('qi', 0.616),
#  ('느린데', 0.616),
#  ('비교적', 0.616),
#  ('타제품', 0.616),
#  ('aux', 0.616),
#  ('부피', 0.615),
#  ('내장형', 0.615),
#  ('기구', 0.6147),
#  ('뒤판', 0.614),
#  ('DIY', 0.614),
#  ('아이피', 0.6133),
#  ('뜨거워지', 0.6133),
#  ('도로는', 0.6133),
#  ('부쩍', 0.6133),
#  ('판다면', 0.6133),
#  ('악세', 0.613),
#  ('수신기', 0.613),
#  ('hdd', 0.613),
#  ('두깨', 0.6123),
#  ('박대', 0.6123),
#  ('엘시디', 0.612),
#  ('만져서', 0.612),
#  ('Ips', 0.612),
#  ('스카이라', 0.612),
#  ('수화기', 0.612),
#  ('철한', 0.612),
#  ('DOCK', 0.612),
#  ('선택지', 0.611),
#  ('수첩', 0.611),
#  ('라이트닝', 0.611),
#  ('부속', 0.611),
#  ('빠져요', 0.611),
#  ('QC', 0.611),
#  ('으다', 0.611),
#  ('도라', 0.611),
#  ('단데', 0.611),
#  ('SAR', 0.611),
#  ('광속', 0.6104),
#  ('수요자', 0.6104),
#  ('전지', 0.61),
#  ('rmaa', 0.61),
#  ('Dmb', 0.61),
#  ('올라갑니다', 0.6094),
#  ('앞판', 0.6094),
#  ('오링', 0.6094),
#  ('비품', 0.6094),
#  ('높였', 0.6094),
#  ('스티치', 0.6094),
#  ('레이터', 0.6094),
#  ('정시', 0.6094),
#  ('멀다하고', 0.6094),
#  ('페화', 0.6094),
#  ('통했', 0.6084),
#  ('통이', 0.6084),
#  ('볼거리', 0.6084),
#  ('철사유', 0.6084),
#  ('렘', 0.608),
#  ('스탠드', 0.608),
#  ('통짜', 0.608),
#  ('딸려온', 0.608),
#  ('실리콘', 0.6074),
#  ('서서히', 0.6074),
#  ('풀로', 0.6074),
#  ('아우라', 0.6074),
#  ('블루스크린', 0.6074),
#  ('제것은', 0.6074),
#  ('쌓여서', 0.6074),
#  ('핸들', 0.6074),
#  ('미락', 0.6074),
#  ('APU', 0.6074),
#  ('심한지', 0.6074),
#  ('소가죽', 0.6074),
#  ('벡', 0.607),
#  ('늘어납니다', 0.607),
#  ('트랙패드', 0.607),
#  ('치고는', 0.607),
#  ('왕조', 0.607),
#  ('EXT', 0.607),
#  ('잔량', 0.6064),
#  ('끼워도', 0.6064),
#  ('실체', 0.6064),
#  ('방향키', 0.6064),
#  ('기대치', 0.606),
#  ('조퇴', 0.606),
#  ('상성', 0.606),
#  ('페블블루는', 0.606),
#  ('두꺼운데', 0.606),
#  ('안드로보이', 0.6055),
#  ('과부하', 0.6055),
#  ('실금', 0.6055),
#  ('에어링크', 0.6055),
#  ('늘어남', 0.6055),
#  ('자석', 0.605),
#  ('개조', 0.605),
#  ('항시', 0.605),
#  ('임신', 0.605),
#  ('늘려서', 0.605),
#  ('끝장', 0.605),
#  ('느려도', 0.605),
#  ('괜찬은데', 0.605),
#  ('글로나스', 0.605),
#  ('진수', 0.605),
#  ('쓸래', 0.605),
#  ('찌그러진', 0.605),
#  ('액세서리', 0.604),
#  ('접착제', 0.604),
#  ('교체기', 0.604),
#  ('빨라집니다', 0.604),
#  ('통실', 0.604),
#  ('부러져서', 0.604),
#  ('첫마디', 0.604),
#  ('타리', 0.604),
#  ('저항', 0.603),
#  ('옆구리', 0.603),
#  ('탈탈', 0.603),
#  ('무거움', 0.603),
#  ('겹쳐', 0.603),
#  ('ㅠㅠ갤럭시', 0.603),
#  ('두려움', 0.603),
#  ('끼니', 0.603),
#  ('완방', 0.603),
#  ('고민거리', 0.603),
#  ('초고속', 0.603),
#  ('케이스', 0.6025),
#  ('여타', 0.6025),
#  ('터치패드', 0.6025),
#  ('기본기', 0.6025),
#  ('쩜', 0.6025),
#  ('문젠', 0.6025),
#  ('빨라도', 0.6025),
#  ('껍질', 0.6025),
#  ('패킷', 0.6025),
#  ('됫죠', 0.6025),
#  ('밀리암페어', 0.6025),
#  ('요놈', 0.602),
#  ('균열', 0.602),
#  ('덮개', 0.602),
#  ('남아도', 0.602),
#  ('DPI', 0.602),
#  ('게임패드', 0.602),
#  ('광고비', 0.602),
#  ('암말', 0.602),
#  ('벗긴', 0.602),
#  ('무거운데', 0.602),
#  ('본체', 0.6016),
#  ('소모량', 0.6016),
#  ('가벼움', 0.6016),
#  ('한물', 0.6016),
#  ('이염', 0.6016),
#  ('멈춥니다', 0.6016),
#  ('할애비', 0.6016),
#  ('분홍', 0.6016),
#  ('걸레', 0.6016),
#  ('부셔지', 0.6016),
#  ('MF', 0.6016),
#  ('Qi', 0.6016),
#  ('고속', 0.6006),
#  ('사제', 0.6006),
#  ('코일', 0.6006),
#  ('바이러스', 0.6006),
#  ('스케일', 0.6006),
#  ('마개', 0.6006),
#  ('정전기', 0.6006),
#  ('오름', 0.6006),
#  ('게이지', 0.6006),
#  ('된다던가', 0.6006),
#  ('Mp', 0.6006),
#  ('악화', 0.6006),
#  ('RF', 0.6006),
#  ('꾸졌', 0.6006),
#  ('LET', 0.6006),
#  ('칩과', 0.6006),
#  ('에보', 0.5996),
#  ('중상', 0.5996),
#  ('소켓', 0.5996),
#  ('요센', 0.5996),
#  ('고자라니', 0.5996),
#  ('체력', 0.5996),
#  ('인화', 0.5996),
#  ('용두', 0.5996),
#  ('변환기', 0.5996),
#  ('태산', 0.5996),
#  ('부드러우', 0.5996),
#  ('ram', 0.599),
#  ('쓸데', 0.599),
#  ('심해져서', 0.599),
#  ('대두', 0.599),
#  ('은박지', 0.599),
#  ('뜨거워졌', 0.599),
#  ('올케', 0.5986),
#  ('주행', 0.5986),
#  ('fhd', 0.5986),
#  ('QD', 0.5986),
#  ('가르', 0.5986),
#  ('뎀비', 0.598),
#  ('대동소이', 0.598),
#  ('요걸로', 0.598),
#  ('전산망', 0.598),
#  ('낍니다', 0.598),
#  ('발열량', 0.598),
#  ('데스크톱', 0.598),
#  ('지피에스', 0.5977),
#  ('KNOX', 0.5977),
#  ('넉넉히', 0.5977),
#  ('지체', 0.5977),
#  ('부속품', 0.5977),
#  ('정감', 0.5977),
#  ('봉실', 0.5977),
#  ('막무가내', 0.5977),
#  ('병목', 0.5977),
#  ('엉덩이', 0.597),
#  ('써봐도', 0.597),
#  ('임피던스', 0.597),
#  ('주변기기', 0.597),
#  ('이질감', 0.597),
#  ('오래간다고', 0.597),
#  ('글로', 0.597),
#  ('끌림', 0.597),
#  ('쓰임새', 0.597),
#  ('빠르기', 0.597),
#  ('카바', 0.597),
#  ('제원', 0.597),
#  ('죽죽', 0.597),
#  ('경도', 0.597),
#  ('특이점', 0.597),
#  ('됏는데', 0.597),
#  ('굴곡진', 0.597),
#  ('성장세', 0.597),
#  ('제아무리', 0.597),
#  ('스콜', 0.597),
#  ('동속', 0.597),
#  ('급속히', 0.597),
#  ('뜨거우', 0.597),
#  ('외관', 0.5967),
#  ('Tmap', 0.5967),
#  ('소나', 0.5967),
#  ('문젠데', 0.5967),
#  ('갔으나', 0.5967),
#  ('대여섯', 0.5967),
#  ('변강쇠가', 0.5967),
#  ('엔하위키', 0.5967),
#  ('한시름', 0.5967),
#  ('포장지', 0.5967),
#  ('mah', 0.596),
#  ('eq', 0.596),
#  ('앞부분', 0.596),
#  ('놀러갔', 0.596),
#  ('발화', 0.596),
#  ('빨라져서', 0.596),
#  ('지폐', 0.596),
#  ('TEGRA', 0.596),
#  ('파랭이', 0.596),
#  ('뒷모습', 0.5957),
#  ('카메라폰', 0.5957),
#  ('괜찬네요', 0.5957),
#  ('노멀', 0.5957),
#  ('젠하이저', 0.5957),
#  ('허덕이', 0.5957),
#  ('착용감', 0.5957),
#  ('늘어난다는', 0.5957),
#  ('결점', 0.5957),
#  ('화재', 0.5957),
#  ('악어', 0.5957),
#  ('악조건', 0.5957),
#  ('속합니다', 0.5957),
#  ('둬도', 0.5957),
#  ('녹아내리', 0.5957),
#  ('파나소닉', 0.595),
#  ('다른데요', 0.595),
#  ('틀려요', 0.595),
#  ('기니', 0.595),
#  ('오른손잡이', 0.595),
#  ('정수', 0.595),
#  ('이어진', 0.595),
#  ('체급', 0.595),
#  ('후처리', 0.595),
#  ('달라져서', 0.595),
#  ('들것', 0.595),
#  ('부푸', 0.595),
#  ('턱주가리', 0.595),
#  ('인방', 0.595),
#  ('별문제', 0.595),
#  ('Knox', 0.595),
#  ('흉하', 0.595),
#  ('글씨체', 0.5947),
#  ('예산', 0.5947),
#  ('거랑', 0.5947),
#  ('정격', 0.5947),
#  ('유막', 0.5947),
#  ('무개', 0.5947),
#  ('뛰어남', 0.5947),
#  ('Kg', 0.5947),
#  ('통철', 0.5947),
#  ('이랜텍', 0.594),
#  ('한대요', 0.594),
#  ('음음', 0.594),
#  ('충천', 0.594),
#  ('프라이버시', 0.594),
#  ('손잡이', 0.594),
#  ('기급', 0.594),
#  ('사이클', 0.594),
#  ('접히', 0.594),
#  ('mha', 0.594),
#  ('재료', 0.5938),
#  ('완벽히', 0.5938),
#  ('모자란', 0.5938),
#  ('난다면', 0.5938),
#  ('밑부분', 0.5938),
#  ('바꾼다', 0.5938),
#  ('뜨끈뜨끈', 0.5938),
#  ('들뜸', 0.5938),
#  ('예비군', 0.5938),
#  ('살돈', 0.5938),
#  ('땡겼', 0.5938),
#  ('Ios', 0.5938),
#  ('랜턴', 0.5938),
#  ('합체', 0.5938),
#  ('키워서', 0.5938),
#  ('신차', 0.5938),
#  ('소비량', 0.5938),
#  ('health', 0.5938),
#  ('후반부', 0.5938),
#  ('갠데', 0.5938),
#  ('다중작업', 0.5938),
#  ('다닐까', 0.5938),
#  ('쩨', 0.5938),
#  ('문제기', 0.5938),
#  ('경이롭', 0.5938),
#  ('GG', 0.5933),
#  ('큐브릭', 0.5933),
#  ('앞선', 0.5933),
#  ('갈기', 0.5933),
#  ('뜨뜻', 0.5933),
#  ('범주', 0.5933),
#  ('근디', 0.5933),
#  ('만만찮', 0.5933),
#  ('커보였', 0.5933),
#  ('수면', 0.5933),
#  ('이치', 0.5933),
#  ('니라', 0.5933),
#  ('얼래', 0.5933),
#  ('품인', 0.5933),
#  ('연통', 0.5933),
#  ('복제', 0.5933),
#  ('qhd', 0.593),
#  ('바꿔왔', 0.593),
#  ('별말', 0.593),
#  ('단다는', 0.593),
#  ('걸릴지', 0.593),
#  ('apu', 0.593),
#  ('디코더', 0.593),
#  ('진거', 0.593),
#  ('단번에', 0.593),
#  ('적다', 0.593),
#  ('미끌미끌', 0.593),
#  ('피사체', 0.593),
#  ('더불어', 0.593),
#  ('망가져', 0.593),
#  ('질주', 0.593),
#  ('갈구', 0.593),
#  ('해상력', 0.593),
#  ('오금', 0.593),
#  ('요베', 0.593),
#  ('제트오디오', 0.593),
#  ('데생각', 0.593),
#  ('하이패스', 0.593),
#  ('거뜬히', 0.5923),
#  ('추이', 0.5923),
#  ('하울링', 0.5923),
#  ('자켓', 0.5923),
#  ('실증', 0.5923),
#  ('바닷물', 0.5923),
#  ('이런가', 0.5923),
#  ('사무', 0.5923),
#  ('끌어안', 0.5923),
#  ('걸려도', 0.5923),
#  ('판때기', 0.5923),
#  ('멀티탭', 0.5923),
#  ('빠진다', 0.5923),
#  ('와서야', 0.5923),
#  ('가벼웠', 0.5923),
#  ('재료비', 0.5923),
#  ('삼각대', 0.5923),
#  ('합쳐져서', 0.5923),
#  ('교통비', 0.5923),
#  ('행사장', 0.5923),
#  ('qx', 0.5923),
#  ('Gps', 0.5923),
#  ('병목현상', 0.5923),
#  ('재고품', 0.5923),
#  ('이라크', 0.5923),
#  ('노화', 0.5923),
#  ('헐거워', 0.5923),
#  ('똥물', 0.5923),
#  ('탈라', 0.5923),
#  ('정나미', 0.5923),
#  ('빠를지', 0.5923),
#  ('열세', 0.5923),
#  ('모래알', 0.5923),
#  ('휑', 0.5923),
#  ('인내', 0.5913),
#  ('지랑', 0.5913),
#  ('자바', 0.5913),
#  ('버퍼', 0.5913),
#  ('들쭉날쭉', 0.5913),
#  ('난적', 0.5913),
#  ('맘놓', 0.5913),
#  ('버텨서', 0.5913),
#  ('졌으나', 0.5913),
#  ('테리', 0.5913),
#  ('넷플릭스', 0.5913),
#  ('탈수', 0.5913),
#  ('괜찬나요', 0.5913),
#  ('끽해야', 0.5913),
#  ('스중', 0.5913),
#  ('아류', 0.5913),
#  ('체면', 0.5913),
#  ('명도', 0.5913),
#  ('터치스톤', 0.5913),
#  ('완전체', 0.591),
#  ('원색', 0.591),
#  ('손난로', 0.591),
#  ('리어', 0.591),
#  ('도면', 0.591),
#  ('들어와도', 0.591),
#  ('왕좌', 0.591),
#  ('과다', 0.591),
#  ('딴건', 0.591),
#  ('토로', 0.591),
#  ('안목', 0.591),
#  ('막연히', 0.591),
#  ('철판', 0.591),
#  ('페블블루에', 0.591),
#  ('이뤄지는', 0.591),
#  ('ㅠㅠ이', 0.591),
#  ('모자람', 0.591),
#  ('물려도', 0.591),
#  ('세나', 0.591),
#  ('휘어짐', 0.591),
#  ('연결선', 0.591),
#  ('철철', 0.591),
#  ('해야겠네', 0.591),
#  ('닌텐도', 0.5903),
#  ('오락가락', 0.5903),
#  ('단선', 0.5903),
#  ('겉보기', 0.5903),
#  ('돕니다', 0.5903),
#  ('반경', 0.5903),
#  ('최곤데', 0.5903),
#  ('몽블랑', 0.5903),
#  ('적수', 0.5903),
#  ('으아아', 0.5903),
#  ('삐걱', 0.5903),
#  ('잠잘', 0.5903),
#  ('기변가', 0.5903),
#  ('후려쳐서', 0.5903),
#  ('강탈', 0.5903),
#  ('mh', 0.5903),
#  ('더래도', 0.5903),
#  ('뭐니뭐니', 0.5903),
#  ('외각', 0.5903),
#  ('중가', 0.5903),
#  ('pin', 0.5903),
#  ('효과음', 0.5903),
#  ('에쿠스', 0.5903),
#  ('악재', 0.5903),
#  ('Class', 0.5903),
#  ('WIMAX', 0.5903),
#  ('ㅡㅋㅋ', 0.5903),
#  ('철개', 0.5903),
#  ('배분', 0.5903),
#  ('따진', 0.5903),
#  ('Tstore', 0.5903),
#  ('스텐', 0.5903),
#  ('갑툭튀', 0.5903),
#  ('세단', 0.5903),
#  ('미관상', 0.5903),
#  ('불량증', 0.5903),
#  ('쪽팔려', 0.5903),
#  ('중형', 0.5903),
#  ('몰딩', 0.5903),
#  ('미세먼지', 0.5903),
#  ('Quill', 0.5903),
#  ('MLC', 0.5903),
#  ('소모품', 0.59),
#  ('유닛', 0.59),
#  ('두꺼워서', 0.59),
#  ('흔들림', 0.59),
#  ('고성능', 0.59),
#  ('가구', 0.59),
#  ('나눠져', 0.59),
#  ('번외', 0.59),
#  ('부담감', 0.59),
#  ('심해졌', 0.59),
#  ('죤', 0.59),
#  ('엄청납니다', 0.59),
#  ('작살나', 0.59),
#  ('관심사', 0.59),
#  ('사로', 0.59),
#  ('쑥쑥', 0.59),
#  ('ㅠㅠ왜', 0.59),
#  ('의정부', 0.59),
#  ('오와', 0.59),
#  ('빨라진다', 0.59),
#  ('소보', 0.59),
#  ('CMOS', 0.59),
#  ('생길까봐', 0.59),
#  ('형편없', 0.5894),
#  ('크래쉬', 0.5894),
#  ('쌍둥이', 0.5894),
#  ('엇비슷', 0.5894),
#  ('버금가', 0.5894),
#  ('과소비', 0.5894),
#  ('만듦새', 0.5894),
#  ('뺴면', 0.5894),
#  ('광학', 0.5894),
#  ('★★★★★', 0.5894),
#  ('괜찬은듯', 0.5894),
#  ('노트라', 0.5894),
#  ('혹해', 0.5894),
#  ('간다는데', 0.5894),
#  ('tn', 0.5894),
#  ('테스트로', 0.5894),
#  ('아이맥', 0.5894),
#  ('인색', 0.5894),
#  ('시끄러웠', 0.5894),
#  ('어두워도', 0.5894),
#  ('까졌', 0.5894),
#  ('두꺼워질', 0.5894),
#  ('배불러요', 0.5894),
#  ('완존', 0.5894),
#  ('외전', 0.5894),
#  ('tlc', 0.5894),
#  ('충전', 0.589),
#  ('후레쉬', 0.589),
#  ('광각', 0.589),
#  ('수준급', 0.589),
#  ('청색', 0.589),
#  ('애물단지', 0.589),
#  ('내버려', 0.589),
#  ('사탕', 0.589),
#  ('일으킨', 0.589),
#  ('날렵', 0.589),
#  ('드리프트', 0.589),
#  ('아낄', 0.589),
#  ('반올림', 0.589),
#  ('적음', 0.589),
#  ('방습', 0.589),
#  ('va', 0.589),
#  ('드이', 0.589),
#  ('악수', 0.589),
#  ('상체', 0.589),
#  ('중첩', 0.589),
#  ('교환기', 0.589),
#  ('Anker', 0.589),
#  ('PHA', 0.589),
#  ('DSD', 0.589),
#  ('SAMOLED', 0.589),
#  ('평상시', 0.5884),
#  ('다녀요', 0.5884),
#  ('획기적으로', 0.5884),
#  ('재고량', 0.5884),
#  ('지리', 0.5884),
#  ('떨어졌었', 0.5884),
#  ('질린다', 0.5884),
#  ('틀린데', 0.5884),
#  ('겉모습', 0.5884),
#  ('잡니다', 0.5884),
#  ('Siri', 0.5884),
#  ('예상외', 0.5884),
#  ('산뜻', 0.5884),
#  ('금세', 0.5884),
#  ('빠진다는', 0.5884),
#  ('메시징', 0.5884),
#  ('청음', 0.5884),
#  ('아웃도어', 0.5884),
#  ('감점', 0.5884),
#  ('심도', 0.5884),
#  ('올라온다', 0.5884),
#  ('부상', 0.5884),
#  ('압살', 0.5884),
#  ('줄때', 0.5884),
#  ('버텨요', 0.5884),
#  ('연분홍', 0.5884),
#  ('가계', 0.5884),
#  ('섭취', 0.5884),
#  ('병실', 0.5884),
#  ('으냐', 0.5884),
#  ('배출', 0.5884),
#  ('TC', 0.5884),
#  ('서둘러서', 0.5884),
#  ('울부짖', 0.5884),
#  ('gh', 0.5884),
#  ('빨르', 0.5884),
#  ('벗겨야', 0.5884),
#  ('마지노', 0.5884),
#  ('현세대', 0.5884),
#  ('에어포트', 0.5884),
#  ('마나', 0.5874),
#  ('덩어리', 0.5874),
#  ('단추', 0.5874),
#  ('식도', 0.5874),
#  ('투용', 0.5874),
#  ('딜레마', 0.5874),
#  ('중실', 0.5874),
#  ('견주', 0.5874),
#  ('오동작', 0.5874),
#  ('발랐', 0.5874),
#  ('실측', 0.5874),
#  ('해야함', 0.5874),
#  ('놀라워', 0.5874),
#  ('뜨거워요', 0.5874),
#  ('된다니까', 0.5874),
#  ('스핑크', 0.5874),
#  ('오릅니다', 0.5874),
#  ('망설여집니다', 0.5874),
#  ('둔다고', 0.5874),
#  ('디지털카메라', 0.5874),
#  ('뒤돌아보', 0.5874),
#  ('이스나', 0.5874),
#  ('저본', 0.5874),
#  ('문안', 0.5874),
#  ('게이밍', 0.5874),
#  ('군사', 0.5874),
#  ('심해져', 0.5874),
#  ('그만뒀', 0.5874),
#  ('iface', 0.5874),
#  ('줄줄', 0.587),
#  ('박이', 0.587),
#  ('링케', 0.587),
#  ('모듈러', 0.587),
#  ('토탈', 0.587),
#  ('설사', 0.587),
#  ('탄성', 0.587),
#  ('휠씬', 0.587),
#  ('중간중간', 0.587),
#  ('흘렀', 0.587),
#  ('gpro', 0.587),
#  ('콘서트', 0.587),
#  ('ext', 0.587),
#  ('색칠', 0.587),
#  ('우드', 0.587),
#  ('IO', 0.587),
#  ('단시간', 0.587),
#  ('멀정', 0.587),
#  ('무거워진', 0.587),
#  ('kT', 0.587),
#  ('유하', 0.587),
#  ('이클립스', 0.587),
#  ('아깐', 0.587),
#  ('완패', 0.587),
#  ('심의', 0.587),
#  ('그러저럭', 0.587),
#  ('튀어나옵니다', 0.587),
#  ('빳데리', 0.587),
#  ('물증', 0.587),
#  ('악세서리', 0.5864),
#  ('가출', 0.5864),
#  ('걸린다', 0.5864),
#  ('돼도', 0.5864),
#  ('실망감', 0.5864),
#  ('탱크', 0.5864),
#  ('늠', 0.5864),
#  ('햅', 0.5864),
#  ('샌디스크', 0.5864),
#  ('골드색', 0.5864),
#  ('이부재', 0.5864),
#  ('ssd', 0.5864),
#  ('그리도', 0.5864),
#  ('생김새', 0.5864),
#  ('반투명', 0.5864),
#  ('ip', 0.5864),
#  ('다를까요', 0.5864),
#  ('비결', 0.5864),
#  ('매트', 0.5864),
#  ('삼과', 0.5864),
#  ('뚝딱', 0.5864),
#  ('어림', 0.5864),
#  ('심박수', 0.5864),
#  ('PDP', 0.5864),
#  ('고른다면', 0.5864),
#  ('일곱', 0.5864),
#  ('벌어짐', 0.5864),
#  ('구구', 0.5864),
#  ('해본다고', 0.5864),
#  ('천지개벽', 0.5864),
#  ('슬펐', 0.5864),
#  ('염치', 0.5864),
#  ('세컨드', 0.5864),
#  ('팔팔', 0.5864),
#  ('지와', 0.5864),
#  ('에이수스', 0.5864),
#  ('빠졌었', 0.5864),
#  ('차인', 0.5864),
#  ('속기', 0.5864),
#  ('면도', 0.5864),
#  ('번뇌', 0.5864),
#  ('한적', 0.5864),
#  ('나아진다', 0.5864),
#  ('원활히', 0.5864),
#  ('설계도', 0.5864),
#  ('요단', 0.5864),
#  ('브렌드', 0.5864),
#  ('철안', 0.5864),
#  ('덜렁거리', 0.5864),
#  ('Zoom', 0.5864),
#  ('여주인공', 0.5864),
#  ('말싸움', 0.5864),
#  ('뚤려', 0.5864),
#  ('순백색', 0.5864),
#  ('SID', 0.5864),
#  ('여름철', 0.5864),
#  ('말끔히', 0.5864),
#  ('비싼데요', 0.5864),
#  ('종균', 0.5864),
#  ('탈탈탈', 0.5864),
#  ('구부러져서', 0.5864),
#  ('대역폭', 0.586),
#  ('앞쪽', 0.586),
#  ('모자르', 0.586),
#  ('증발', 0.586),
#  ('썻습니다', 0.586),
#  ('가사', 0.586),
#  ('손안', 0.586),
#  ('제트', 0.586),
#  ('평면', 0.586),
#  ('콸콸', 0.586),
#  ('다녔었', 0.586),
#  ('가벼우', 0.586),
#  ('내놔', 0.586),
#  ('놉', 0.586),
#  ('마이크로', 0.586),
#  ('격자무늬', 0.586),
#  ('티렉스', 0.586),
#  ('흥했', 0.586),
#  ('양옆', 0.586),
#  ('힘겹', 0.586),
#  ('달초', 0.586),
#  ('상심', 0.586),
#  ('수수', 0.586),
#  ('용이성', 0.586),
#  ('무결', 0.586),
#  ('후방', 0.586),
#  ('외상', 0.586),
#  ('고르기', 0.586),
#  ('도망', 0.586),
#  ('아웃풋', 0.586),
#  ('똑딱', 0.586),
#  ('재와', 0.586),
#  ('격려', 0.586),
#  ('직찍', 0.586),
#  ('새것', 0.5854),
#  ('이온', 0.5854),
#  ('고용량', 0.5854),
#  ('SE', 0.5854),
#  ('래들', 0.5854),
#  ('로그', 0.5854),
#  ('탄지', 0.5854),
#  ('노스', 0.5854),
#  ('모코', 0.5854),
#  ('누래지', 0.5854),
#  ('떔에', 0.5854),
#  ('감탄사', 0.5854),
#  ('릴레이', 0.5854),
#  ('주방', 0.5854),
#  ('여파', 0.5854),
#  ('미라클', 0.5854),
#  ('든든', 0.5854),
#  ('꼴찌', 0.5854),
#  ('견', 0.5854),
#  ('ㅜㅠㅠ', 0.5854),
#  ('금번', 0.5854),
#  ('나빠진', 0.5854),
#  ('식인', 0.5854),
#  ('대투', 0.5854),
#  ('방열판', 0.5854),
#  ('심해도', 0.5854),
#  ('간만', 0.5854),
#  ('르그랑', 0.5854),
#  ('쪽박', 0.5854),
#  ('괜찬은거', 0.5854),
#  ('급기야', 0.5854),
#  ('톡톡이', 0.5854),
#  ('ㅜㅜ흑', 0.5854),
#  ('깨어나', 0.5854),
#  ('sdxc', 0.5854),
#  ('하차', 0.5854),
#  ('위인', 0.5854),
#  ('언젠데요', 0.5854),
#  ('했었으니', 0.5854),
#  ('산후', 0.5854),
#  ('매칭', 0.585),
#  ('훅훅', 0.585),
#  ('아홉', 0.585),
#  ('음색', 0.585),
#  ('혐', 0.585),
#  ('깍두기', 0.585),
#  ('메이주', 0.585),
#  ('강압', 0.585),
#  ('수습', 0.585),
#  ('해봅시다', 0.585),
#  ('압축률', 0.585),
#  ('구식', 0.585),
#  ('은하수', 0.585),
#  ('개량', 0.585),
#  ('올라감', 0.585),
#  ('두드러지', 0.585),
#  ('Lcd', 0.585),
#  ('급상승', 0.585),
#  ('준하', 0.585),
#  ('베루스', 0.585),
#  ('나와랏', 0.585),
#  ('징그럽', 0.585),
#  ('낼모레', 0.585),
#  ('앞모습', 0.585),
#  ('터무니', 0.585),
#  ('Evo', 0.585),
#  ('IN', 0.585),
#  ('도니', 0.585),
#  ('생겼었', 0.585),
#  ('으믄', 0.585),
#  ('데크', 0.585),
#  ('통채', 0.585),
#  ('무수히', 0.585),
#  ('속상해요', 0.585),
#  ('지퍼', 0.585),
#  ('버금', 0.585),
#  ('기일', 0.585),
#  ('스케일링', 0.585),
#  ('동강', 0.585),
#  ('성면', 0.585),
#  ('무서울', 0.585),
#  ('오랬', 0.585),
#  ('자수', 0.585),
#  ('Tegra', 0.585),
#  ('어감', 0.585),
#  ('셀러론', 0.585),
#  ('딸린다', 0.585),
#  ('ㅇㅁㅇ', 0.585),
#  ('사나이', 0.585),
#  ('굴려서', 0.585),
#  ('오밀조밀', 0.585),
#  ('신봉자', 0.585),
#  ('수박', 0.585),
#  ('보요', 0.585),
#  ('차츰', 0.585),
#  ('운속', 0.585),
#  ('TLC', 0.585),
#  ('내구력', 0.585),
#  ('스윙', 0.585),
#  ('지그', 0.585),
#  ('Rgb', 0.585),
#  ('촉박', 0.585),
#  ('구리구리', 0.585),
#  ('던걸요', 0.585),
#  ('날아간', 0.585),
#  ('떠버렸', 0.585),
#  ('EVDO', 0.585),
#  ('SET', 0.585),
#  ('이상태', 0.585),
#  ('끝난지', 0.585),
#  ('티어', 0.585),
#  ('끊임', 0.585),
#  ('기방', 0.585),
#  ('제조자', 0.585),
#  ('랍디다', 0.585),
#  ('했었으나', 0.585),
#  ('볼드', 0.585),
#  ('기술자', 0.585),
#  ('피에스', 0.585),
#  ('상국', 0.585),
#  ('맞춰도', 0.585),
#  ('카드기', 0.585),
#  ('스캐닝', 0.585),
#  ('끄적거려', 0.585),
#  ('약했', 0.585),
#  ('SDRAM', 0.585),
#  ('소모전', 0.5845),
#  ('과자', 0.5845),
#  ('화딱지', 0.5845),
#  ('본가', 0.5845),
#  ('에이급', 0.5845),
#  ('감이', 0.5845),
#  ('비워', 0.5845),
#  ('추우', 0.5845),
#  ('개발비', 0.5845),
#  ('exif', 0.5845),
#  ('트러블', 0.5845),
#  ('주된', 0.5845),
#  ('번화가', 0.5845),
#  ('드러납니다', 0.5845),
#  ('공법', 0.5845),
#  ('한족', 0.5845),
#  ('근사', 0.5845),
#  ('트라우마', 0.5845),
#  ('겉모양', 0.5845),
#  ('천연', 0.5845),
#  ('내릴까요', 0.5845),
#  ('이릅니다', 0.5845),
#  ('루미', 0.5845),
#  ('어선지', 0.5845),
#  ('저음부', 0.5845),
#  ('이등', 0.5845),
#  ('특혜', 0.5845),
#  ('엘라', 0.5845),
#  ('밑장', 0.5845),
#  ('꼬리표', 0.5845),
#  ('기와', 0.5845),
#  ('쏠렸', 0.5845),
#  ('탁상', 0.5845),
#  ('숙모', 0.5845),
#  ('통매', 0.5845),
#  ('트릭', 0.5845),
#  ('lgd', 0.5845),
#  ('vm', 0.5845),
#  ('멈칫하', 0.5845),
#  ('LP', 0.5845),
#  ('고음부', 0.5845),
#  ('진동판', 0.5845),
#  ('스크래치', 0.584),
#  ('플레시', 0.584),
#  ('견적', 0.584),
#  ('orz', 0.584),
#  ('태양', 0.584),
#  ('한달', 0.584),
#  ('싼데', 0.584),
#  ('너도나도', 0.584),
#  ...]

# %% [markdown]
# ## Document-Term Matrix 구축

# %%
corpus = open("data/phone_review_mecab.txt", "r", encoding="utf-8").readlines()
corpus = list(set([el.strip() for el in corpus if len(el.split()) < 31]))

# %%
import random
corpus = random.sample(corpus, 3000)

# %%
from sklearn.feature_extraction.text import CountVectorizer

vectorizer = CountVectorizer(vocabulary=vocab
                             , binary=True # 해당 단어가 1 번 이상 쓰였으면 1
                             , ngram_range=(1, 1) # 한 단어씩 
                             , tokenizer=lambda x: x.strip().split()) # tokenizer 는 공백으로 split

# %%
dtm = vectorizer.fit_transform(corpus).toarray()
word_counts_per_doc = np.sum(dtm, axis=1) 
result = np.dot(dtm, weight_matrix.T)

# %%
# 문서 사이즈(말뭉치), vocab 사이즈
dtm.shape
# Out:
# (3000, 23599)

# %%
word_counts_per_doc
# Out:
# array([10,  9,  7, ..., 19,  2, 13], dtype=int64)

# %%
word_counts_per_doc ** 0.6
# Out:
# array([3.98107171, 3.73719282, 3.21409585, ..., 5.85129724, 1.51571657,
#        4.65978642])

# %% [markdown]
# ## 최종 결과물 도출

# %%
for func_idx, func in enumerate(functions):
    print("##### " + func)

    # 아래에 (-) 부호 붙여주는 이유는 내림차순으로 보기위한 트릭
    scores = - result[:, func_idx] / (word_counts_per_doc ** 0.6) # 문장을 구성하는 단어 수로 나눠주어서 단어 갯수 때문에 영향받지 않게 한다, 0.6 을 제곱해준건 smoothing 해준 것
    for sent_idx in scores.argsort()[:10]:
        # 원래 데이터 그대로 보기 위해 다시 (-) 부호 붙여준다
        print(corpus[sent_idx].strip(), - scores[sent_idx])
    print("\n")
# Out:
# ##### 배터리
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.5756941888207259
# 그렇 군요 다만 너무 비싼 가격 과 화면 크기 작음 과 배터리 내장 이 라서 이 3 가지 만 따져도 갤 s 3 승리 전 옵 이 이 유저 임다 1.556766978112604
# 이건 옴니아 2 윈 모지 우고 안드로이드 깔 아도 이거 랑 비슷 할 텐데 ㅋ 이제 하드웨어 는 고만고만 하 고 이제 소프트웨어 로 평가 가 갈리 네요 1.5434776656613163
# 시리우스 가 감 악식 이 라 습도 가 높 은 장마철 에 터치 패널 과 액정 이 들러붙 어서 터치 가 고자 가 되 는 종 특이 있 었 습니다 1.5134640131302755
# 일단 미디어 데 이때 겔 럭 시 노트 ap 알려 주 는 부분 에서 1 5 듀얼 코어 로 끝냈 다는 게 문제 1 0 초 정도 설명 했 나 1.4961488851467812
# 조금 늦 게 나와도 발열 과 배터리 만 해결 되 서 나오 면 후면 배꼽 디자인 은 애교 로 봐 줘야 겠 네요 ㅋㅋ 1.4874967409968187
# 저 도 2 년 7 달째 사용 중 고장 도 안 나 고 다만 배터리 가 6 시간 정품 큰 거 쓰 는데 ㅠ 1.487016430207233
# 다행히 부품 수급 문제 로 바뀐 텀블러 디자인 이 1 차 보다 개인 적 기준 에서 는 맘 에 안 든다 는 아니 고 암튼 그래서 좀 다행 이 네요 1.472918686659656
# 저 는 하나 만 교환 받 고 하나 는 못 받 아서 작년 말 에 대용량 배터리 1 개 도 구매 해서 3 개 씁니다 1.4695747770908933
# 씨 피 유부 터 옵 쥐 가 더 좋 아요 카메라 배터리 외장 메모리 sd 카드 로 까이 는 거 지 1.4681602509558895
#
#
# ##### 촬영
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.586638116816606
# 어제 엑페 에다가 안드로이드 해 봣는데 잘 되 더군요 유튜브 동영상 오브제 이런 거 는 안 되 지만 ㅋ 마켓 에서 앱 다운 해서 실행 도 해 보 고 1.5783778329180678
# 예 노트 보다 코덱 지원 은 더 나 은 편 입니다 물론 동영상 화질 도 단지 화면 크기 에서 밀리 죠 현재 저 도 노트 사용자 1.548777020533094
# 가끔 PC 방 계산 할 때 관리 하 는 컴퓨터 모니터 보 면 PC 방 자리 표시 격자 무늬 로 남 아 있 잖아요 그것 과 똑같 네요 ㅠㅠ 1.5287778783693038
# 일단 미디어 데 이때 겔 럭 시 노트 ap 알려 주 는 부분 에서 1 5 듀얼 코어 로 끝냈 다는 게 문제 1 0 초 정도 설명 했 나 1.5277462649862943
# 불편 한 게 아니 라 거슬리 죠 차라리 고정 이 되 어 있 던가 나타났 다 없 어 졌 다 그러니까 영상 볼 때 비율 이 막 왔다갔다 거려서 거슬림 1.522034355460741
# 후속 나와도 4 3 예상 이 라 동영상 보 기 엔 별로 일거 에 요 동영상 목적 이 라면 좀 커도 탭 s 1 0 5 도 괜찮 죠 1.5196838300208035
# 루나 는 고려 하 지 않 았었 는데 이런 변수 가 있 었 군요 ㅎㅎ 사진 까지 캡쳐 해 주 시 고 ㅠㅠ 다시 생각 해봐야 겠 네요 고맙 습니다 1.5163668494110902
# 애플 도 마찬가지 일 듯 요 재판 에서 당연히 이기 려면 유리 한 거 위주 로 구성 하 겠 죠 그걸 판단 하 라고 있 는 게 판사 인데요 ＊ 1.509228128441006
# 플 래쉬 는 사진 찍 는 곳 에서 메뉴 눌러서 찾아보 면 번개 모양 같 은 거 나옵니다 그 중 에 선택 하 면 되 요 ㅋ 1.5075629342288162
#
#
# ##### 디자인
# 이건 옴니아 2 윈 모지 우고 안드로이드 깔 아도 이거 랑 비슷 할 텐데 ㅋ 이제 하드웨어 는 고만고만 하 고 이제 소프트웨어 로 평가 가 갈리 네요 1.5393887593111242
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.530496758094538
# 다행히 부품 수급 문제 로 바뀐 텀블러 디자인 이 1 차 보다 개인 적 기준 에서 는 맘 에 안 든다 는 아니 고 암튼 그래서 좀 다행 이 네요 1.5065761306661951
# 엘지 가 스마트폰 시장 에 늦 게 뛰 어 늘 어서 지금 까지 고전 하 고 있 지만 디자인 하나 는 피쳐 폰 때 부터 먹 어 주 죠 1.4973012786145874
# 저 도 디자인 이 맘 에 들 어요 흔하 지 않 고 근데 요즘 많이 팔리 는 거 같 아서 ㅎ 그래도 색상 이 여러 가지 니 1.485939869067338
# 전 개티 베가 x 쓰 는데 시리우스 가 너무 탐 이나 여 개인 적 으로 는 진짜 스카이 가 디자인 은 최고 인 거 같 아요 1.4746859660864051
# 넥서스 원 인 줄 알 았 네요 ㅎㅎ 그리고 예전 에 잠시 쓰 던 슬라이드 폰 처럼 생기 기 도 했 고 그래도 미끈 하 게 잘 빠졌 네요 ㅋ 1.4653284900574202
# 시리우스 가 감 악식 이 라 습도 가 높 은 장마철 에 터치 패널 과 액정 이 들러붙 어서 터치 가 고자 가 되 는 종 특이 있 었 습니다 1.4610942631851478
# 애플 도 마찬가지 일 듯 요 재판 에서 당연히 이기 려면 유리 한 거 위주 로 구성 하 겠 죠 그걸 판단 하 라고 있 는 게 판사 인데요 ＊ 1.4553248113992137
# 그렇 군요 다만 너무 비싼 가격 과 화면 크기 작음 과 배터리 내장 이 라서 이 3 가지 만 따져도 갤 s 3 승리 전 옵 이 이 유저 임다 1.4519912110824975
#
#
# ##### 화면
# 아몰 레기 가 쓸수록 색감 이 변해요 인터넷 문서 작업 주류 인 사람 일 경우 특히 심해요 흰 화면 눈 이 아파 ㅜ 1.6095342796709784
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.5910024627243284
# 예 노트 보다 코덱 지원 은 더 나 은 편 입니다 물론 동영상 화질 도 단지 화면 크기 에서 밀리 죠 현재 저 도 노트 사용자 1.5822988831135762
# 그렇 군요 다만 너무 비싼 가격 과 화면 크기 작음 과 배터리 내장 이 라서 이 3 가지 만 따져도 갤 s 3 승리 전 옵 이 이 유저 임다 1.54846180308668
# 불편 한 게 아니 라 거슬리 죠 차라리 고정 이 되 어 있 던가 나타났 다 없 어 졌 다 그러니까 영상 볼 때 비율 이 막 왔다갔다 거려서 거슬림 1.543085384768417
# 가끔 PC 방 계산 할 때 관리 하 는 컴퓨터 모니터 보 면 PC 방 자리 표시 격자 무늬 로 남 아 있 잖아요 그것 과 똑같 네요 ㅠㅠ 1.5298930346466288
# 화면 도 안 켰 는데 켜 짐 이 저렇 게 나오 네요 뭔가 문제 가 있 는 듯 해요 ㅠㅠㅠ이거 또 서비스 센터 가 봐야 하 는 건가 ㅋㅋ ㅠㅠ 1.5264243073853303
# 시리우스 가 감 악식 이 라 습도 가 높 은 장마철 에 터치 패널 과 액정 이 들러붙 어서 터치 가 고자 가 되 는 종 특이 있 었 습니다 1.5238364151277175
# 아크 릭스 는 ppi 가 높 아서 펜타일 이 라도 도트 는 눈 에 안 보이 더군요 근데 그 탓 인지 뭔지 약간 지글지글 한 느낌 은 있 더군요 1.5212047582466455
# 그러 게 요 저 도 그거 듣 는 순간 왜 내 가 저 장면 을 알 아야 하나 하 고 버스 에서 내내 최 책 감 에 시달렸 네요 ㅠㅠ 1.5126756789713374
#
#
# ##### OS
# 이건 옴니아 2 윈 모지 우고 안드로이드 깔 아도 이거 랑 비슷 할 텐데 ㅋ 이제 하드웨어 는 고만고만 하 고 이제 소프트웨어 로 평가 가 갈리 네요 1.6343122133416144
# 일단 미디어 데 이때 겔 럭 시 노트 ap 알려 주 는 부분 에서 1 5 듀얼 코어 로 끝냈 다는 게 문제 1 0 초 정도 설명 했 나 1.513954785671097
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.5020623832411937
# 어제 엑페 에다가 안드로이드 해 봣는데 잘 되 더군요 유튜브 동영상 오브제 이런 거 는 안 되 지만 ㅋ 마켓 에서 앱 다운 해서 실행 도 해 보 고 1.4787570341254201
# 엘지 가 스마트폰 시장 에 늦 게 뛰 어 늘 어서 지금 까지 고전 하 고 있 지만 디자인 하나 는 피쳐 폰 때 부터 먹 어 주 죠 1.4779592910689985
# 애플 도 마찬가지 일 듯 요 재판 에서 당연히 이기 려면 유리 한 거 위주 로 구성 하 겠 죠 그걸 판단 하 라고 있 는 게 판사 인데요 ＊ 1.4696666549124353
# 시리우스 가 감 악식 이 라 습도 가 높 은 장마철 에 터치 패널 과 액정 이 들러붙 어서 터치 가 고자 가 되 는 종 특이 있 었 습니다 1.4514834711245808
# 해당 사진 은 그냥 근거 없 는 루머 의 일종 으로 보 면 된다 고 일축 했 다 근데 왜 보안 누출 이 라며 삭제 했 을까요 1.4432508303783593
# 당연히 난리 납니다 디파이 보다 뛰어난 폰 현재 몇 기종 안 됩니다 갤 스 옹 베가스 개티 마하 애매 허 네요 르 그 에 엘 적 화 라 정도 1.4419218244590923
# 노트 가 삼성 의 진정 한 플래그 쉽 폰 이 죠 사실 S 시리즈 는 이제 대중 성 시장 반응 간 보기 용 같 아요 1.4345829839539233
#
#
# ##### 색
# 전 에 정가 주 고 검정 색 질렀었 는데 저렴 해서 흰색 으로 2 개 질렀 습니다 폰 이 흰색 이 니 색깔 맞 는 걸로 구입 했 네요 1.6677669327368694
# 오메 잠바 주머니 에 넣 어 놨더니 뜨끈뜨끈 ㅋㅋ 손난로 인데요 허허 제 미라크 가 문제 인가요 아이폰 은 그렇게 따뜻 하 지 않 은데 미라크 가 이상 해요 후후 1.560385914917123
# 아크 릭스 는 ppi 가 높 아서 펜타일 이 라도 도트 는 눈 에 안 보이 더군요 근데 그 탓 인지 뭔지 약간 지글지글 한 느낌 은 있 더군요 1.521377590999582
# 다행히 부품 수급 문제 로 바뀐 텀블러 디자인 이 1 차 보다 개인 적 기준 에서 는 맘 에 안 든다 는 아니 고 암튼 그래서 좀 다행 이 네요 1.513976713233898
# 시리우스 가 감 악식 이 라 습도 가 높 은 장마철 에 터치 패널 과 액정 이 들러붙 어서 터치 가 고자 가 되 는 종 특이 있 었 습니다 1.495257908924975
# 펜타일 이 라서 일단 패스 했 는데 생긴 것 도 갤 투 화이트 랑 별로 틀리 지 않 게 생겼 는데 이상 하 게 급 땡 깁니다 왜 그럴까요 1.495003312901459
# 애플 도 마찬가지 일 듯 요 재판 에서 당연히 이기 려면 유리 한 거 위주 로 구성 하 겠 죠 그걸 판단 하 라고 있 는 게 판사 인데요 ＊ 1.4931056948753527
# 저 도 디자인 이 맘 에 들 어요 흔하 지 않 고 근데 요즘 많이 팔리 는 거 같 아서 ㅎ 그래도 색상 이 여러 가지 니 1.4881340262522997
# 그러 게 요 저 도 그거 듣 는 순간 왜 내 가 저 장면 을 알 아야 하나 하 고 버스 에서 내내 최 책 감 에 시달렸 네요 ㅠㅠ 1.484737252516598
# 넥서스 원 인 줄 알 았 네요 ㅎㅎ 그리고 예전 에 잠시 쓰 던 슬라이드 폰 처럼 생기 기 도 했 고 그래도 미끈 하 게 잘 빠졌 네요 ㅋ 1.4831667649463256
# C:\Users\Minju\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in true_divide
#   """
