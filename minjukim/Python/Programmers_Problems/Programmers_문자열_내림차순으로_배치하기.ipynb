# %%
s = 'Zbcdefg'

# %%
s[::-1]
# Out:
# 'gfedcbZ'

# %%
sorted(s)
# Out:
# ['Z', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
''.join(sorted(s))
# Out:
# 'Zbcdefg'

# %%
s.islower()
# Out:
# False

# %%
a = 'asd'
a.islower()
# Out:
# True

# %%
''.join(sorted((a for a in s if a.islower()), reverse=True) + sorted(a for a in s if a.isupper()))
# Out:
# 'gfedcbZ'
